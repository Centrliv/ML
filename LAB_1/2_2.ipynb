# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
STEP = 0.1
x = np.linspace(-5,5,int(input()))

f = x - (np.power(x, 3)/6) + (np.power(x, 5)/120) - (np.power(x, 7)/5040)
plt.plot(x, f)
plt.show()
# Out:
# 100

# %%
g = np.sin(x)
plt.plot(x, g)
plt.show()

# %%
plt.plot(x, f, x, g)
