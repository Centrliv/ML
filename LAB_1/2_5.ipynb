# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
x = np.linspace(-5, 5, int(input()))
f = np.sin(x)
g = np.diff(f)/np.diff(x)
a = np.cos(x)
plt.plot(x[1:],g,x,a)
# Out:
# 100
# ...
